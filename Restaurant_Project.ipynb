# %% [markdown]
# ## Analyst Data Processing Fee 2018 VS 2019

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline

# %% [markdown]
# ### Import CSV Data to DataFrame

# %%
pwd
# Out:
# '/Users/williamcheng/Desktop/AData Analyst/Restaurant'

# %%
df1 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (1).csv')
df2 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (2).csv')
df3 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (3).csv')
df4 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (4).csv')
df5 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (5).csv')
df6 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (6).csv')
df7 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (7).csv')
df8 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (8).csv')
df9 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (9).csv')
df10 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (10).csv')
df11 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (11).csv')
df12 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2017/transactions (12).csv')
df13 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (1).csv')
df14 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (2).csv')
df15 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (3).csv')
df16 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (4).csv')
df17 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (5).csv')
df18 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (6).csv')
df19 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (7).csv')
df20 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (8).csv')
df21 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (9).csv')
df22 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (10).csv')
df23 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (11).csv')
df24 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2018/transactions (12).csv')
df25 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (1).csv')
df26 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (2).csv')
df27 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (3).csv')
df28 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (4).csv')
df29 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (5).csv')
df30 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (6).csv')
df31 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (7).csv')
df32 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (8).csv')
df33 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (9).csv')
df34 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (10).csv')
df35 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (11).csv')
df36 = pd.read_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/OE2019/transactions (12).csv')

# %% [markdown]
# #### Combine CSV File to Single CSV File

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36], axis=0)

# %%
df.head()
# Out:
#                           ID                               Restaurant  \
# 0  O-FYA-32433-1483396949933  Oriental Express - Centreville Crest Ln
# 1  O-VTV-36764-1483750154989  Oriental Express - Centreville Crest Ln
# 2  O-9CJ-41506-1485117681409  Oriental Express - Centreville Crest Ln
# 3  O-63C-28997-1484343716432  Oriental Express - Centreville Crest Ln
# 4  O-VTV-36764-1483750154989  Oriental Express - Centreville Crest Ln
#
#                                       Type                       Description  \
# 0                            Prepaid Order                               NaN
# 1  Adjustment of O-VTV-36764-1483750154989  Upcharge for chicken fried rice.
# 2                               Cash Order                               NaN
# 3                            Prepaid Order                               NaN
# 4                            Prepaid Order                               NaN
#
#       Date     Time  Subtotal  Service  Delivery   Tax   Tip  \
# ...

# %%
# df.to_csv('/Users/williamcheng/Desktop/Coursera- Python/Bobby/combinefile.csv')

# %% [markdown]
# ### Delete Useless -Columns

# %%
df.drop(['Restaurant', 'Description', 
                'Service', 'Withheld Tax'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                           ID                                     Type  \
# 0  O-FYA-32433-1483396949933                            Prepaid Order
# 1  O-VTV-36764-1483750154989  Adjustment of O-VTV-36764-1483750154989
# 2  O-9CJ-41506-1485117681409                               Cash Order
# 3  O-63C-28997-1484343716432                            Prepaid Order
# 4  O-VTV-36764-1483750154989                            Prepaid Order
#
#       Date     Time  Subtotal  Delivery   Tax   Tip  Restaurant Total  \
# 0   1/2/17  5:42 PM     30.80       2.0  1.85  4.00             38.65
# 1   1/6/17  7:57 PM      0.00       0.0  0.00  0.00              0.53
# 2  1/22/17  3:41 PM     16.25       2.0  0.98  0.00             19.23
# 3  1/13/17  5:13 PM     19.45       2.0  1.17  4.52             27.14
# 4   1/6/17  7:49 PM     20.45       2.0  1.23  4.74             28.42
#
#    Commission  Processing Fee
# 0       -3.28           -1.48
# 1        0.00            0.00
# ...

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Data Cleaning </h1>

# %%
# Check # of Row and Column in the Dataframe

df.shape
# Out:
# (12064, 11)

# %%
# Evaluating for missing Data
miss_data = df.isnull()
miss_data.head(5)
# Out:
#       ID   Type   Date   Time  Subtotal  Delivery    Tax    Tip  \
# 0  False  False  False  False     False     False  False  False
# 1  False  False  False  False     False     False  False  False
# 2  False  False  False  False     False     False  False  False
# 3  False  False  False  False     False     False  False  False
# 4  False  False  False  False     False     False  False  False
#
#    Restaurant Total  Commission  Processing Fee
# 0             False       False           False
# 1             False       False           False
# 2             False       False           False
# 3             False       False           False
# 4             False       False           False

# %% [markdown]
# "True" stands for missing value, while "False" stands for not missing value

# %%
# Count total NaN at each column in DataFrame
df.isnull().sum()
# Out:
# ID                   0
# Type                34
# Date                 0
# Time                 0
# Subtotal             0
# Delivery             0
# Tax                  0
# Tip                  0
# Restaurant Total     0
# Commission           0
# Processing Fee       0
# dtype: int64

# %%
# Count missing values in each column
for column in miss_data:
    print (miss_data[column].value_counts())
    print("-----------------------------------------")
# Out:
# False    12064
# Name: ID, dtype: int64
# -----------------------------------------
# False    12030
# True        34
# Name: Type, dtype: int64
# -----------------------------------------
# False    12064
# Name: Date, dtype: int64
# -----------------------------------------
# False    12064
# Name: Time, dtype: int64
# -----------------------------------------
# False    12064
# Name: Subtotal, dtype: int64
# -----------------------------------------
# False    12064
# Name: Delivery, dtype: int64
# -----------------------------------------
# False    12064
# Name: Tax, dtype: int64
# -----------------------------------------
# False    12064
# Name: Tip, dtype: int64
# -----------------------------------------
# False    12064
# Name: Restaurant Total, dtype: int64
# -----------------------------------------
# False    12064
# Name: Commission, dtype: int64
# -----------------------------------------
# False    12064
# Name: Processing Fee, dtype: int64
# ...

# %%
# List all Value in "Type" Column
df['Type'].value_counts()
# Out:
# Prepaid Order                      10708
# Cash Order                           673
# Phone Order                          452
# ?                                     32
# Account Adjustment                     8
#                                    ...
# Adjustment of O-272107395831335        1
# Adjustment of O-880401573895721        1
# Adjustment of O-814706177645552        1
# Adjustment of O-676306201165172        1
# Adjustment of O-974304254646917        1
# Name: Type, Length: 149, dtype: int64

# %% [markdown]
# ### remove Row contain Text "Adjustment"

# %%
df['Type'] = df['Type'].astype(str)

# %%
df[df['Type'].str.contains('Adjustment')]
# Out:
#                               ID                                       Type  \
# 1      O-VTV-36764-1483750154989    Adjustment of O-VTV-36764-1483750154989
# 61                   T-226178337                         Account Adjustment
# 69     O-3N5-65345-1484440298270    Adjustment of O-3N5-65345-1484440298270
# 121  O-TTY-1540284-1483299920500  Adjustment of O-TTY-1540284-1483299920500
# 255   O-ABL-151775-1484073555749   Adjustment of O-ABL-151775-1484073555749
# ..                           ...                                        ...
# 4              O-135509952901531            Adjustment of O-135509952901531
# 6              O-135509952901531            Adjustment of O-135509952901531
# 207            O-621009969841768            Adjustment of O-621009969841768
# 330            O-166910177527932            Adjustment of O-166910177527932
# 372            O-621809925651406            Adjustment of O-621809925651406
#
# ...

# %%
df = df[~df.Type.str.contains('Adjustment')]

# %%
df.head()
# Out:
#                           ID           Type     Date     Time  Subtotal  \
# 0  O-FYA-32433-1483396949933  Prepaid Order   1/2/17  5:42 PM     30.80
# 2  O-9CJ-41506-1485117681409     Cash Order  1/22/17  3:41 PM     16.25
# 3  O-63C-28997-1484343716432  Prepaid Order  1/13/17  5:13 PM     19.45
# 4  O-VTV-36764-1483750154989  Prepaid Order   1/6/17  7:49 PM     20.45
# 5  O-7P8-75823-1483834292972  Prepaid Order   1/7/17  7:11 PM     15.00
#
#    Delivery   Tax   Tip  Restaurant Total  Commission  Processing Fee
# 0       2.0  1.85  4.00             38.65       -3.28           -1.48
# 2       2.0  0.98  0.00             19.23       -1.83            0.00
# 3       2.0  1.17  4.52             27.14       -2.15           -1.13
# 4       2.0  1.23  4.74             28.42       -2.25           -1.17
# 5       2.0  0.90  3.58             21.48       -1.70           -0.96

# %%
df['Type'].value_counts()
# Out:
# Prepaid Order    10708
# Cash Order         673
# Phone Order        452
# nan                 34
# ?                   32
# Name: Type, dtype: int64

# %% [markdown]
# ### Change "?" to "nan" ,  Replace "nan" With "Prepaid Order"

# %%
df.replace("?", np.nan, inplace = True)
df.shape
# Out:
# (11899, 11)

# %%
# replace the'nan' values by the most frequent 
df['Type'].value_counts().idxmax
# Out:
# <bound method Series.idxmax of Prepaid Order    10708
# Cash Order         673
# Phone Order        452
# nan                 34
# Name: Type, dtype: int64>

# %%
# replace the'nan' values With "Prepaid Order"
df.replace("nan", 'Prepaid Order', inplace = True)
df['Type'].value_counts()
# Out:
# Prepaid Order    10742
# Cash Order         673
# Phone Order        452
# Name: Type, dtype: int64

# %%
df.dtypes
# Out:
# ID                   object
# Type                 object
# Date                 object
# Time                 object
# Subtotal            float64
# Delivery            float64
# Tax                 float64
# Tip                 float64
# Restaurant Total    float64
# Commission          float64
# Processing Fee      float64
# dtype: object

# %%
df.head()
# Out:
#                           ID           Type     Date     Time  Subtotal  \
# 0  O-FYA-32433-1483396949933  Prepaid Order   1/2/17  5:42 PM     30.80
# 2  O-9CJ-41506-1485117681409     Cash Order  1/22/17  3:41 PM     16.25
# 3  O-63C-28997-1484343716432  Prepaid Order  1/13/17  5:13 PM     19.45
# 4  O-VTV-36764-1483750154989  Prepaid Order   1/6/17  7:49 PM     20.45
# 5  O-7P8-75823-1483834292972  Prepaid Order   1/7/17  7:11 PM     15.00
#
#    Delivery   Tax   Tip  Restaurant Total  Commission  Processing Fee
# 0       2.0  1.85  4.00             38.65       -3.28           -1.48
# 2       2.0  0.98  0.00             19.23       -1.83            0.00
# 3       2.0  1.17  4.52             27.14       -2.15           -1.13
# 4       2.0  1.23  4.74             28.42       -2.25           -1.17
# 5       2.0  0.90  3.58             21.48       -1.70           -0.96

# %%
# Export to CSV format file.
df.to_csv('/Users/williamcheng/Desktop/AData Analyst/Restaurant/NewFile1.csv')

# %% [markdown]
# ### Examine the correlation between 'Restaurant Total' and "Subtotal"

# %%
sns.regplot(x="Restaurant Total", y="Subtotal", data=df)
plt.ylim(0,)
# Out:
# (0, 156.93919426048564)

# %%
# see if "Restaurant Total" as a predictor variable of "Subtotal".
df[['Restaurant Total', 'Subtotal']].corr()
# Out:
#                   Restaurant Total  Subtotal
# Restaurant Total          1.000000  0.949748
# Subtotal                  0.949748  1.000000

# %% [markdown]
# ### Shows Restaurant Prepaid Order Processing Fee

# %%
from IPython.display import Image

# %%
path = "/Users/williamcheng/Desktop/AData Analyst/Restaurant/Prepaid_Order_Fee1.jpg"
Image(filename = path, width=1000, height=100)

# %% [markdown]
# ### Shows Restaurant Prepaid Order Processing Fee 2018 VS 2019

# %%
path = "/Users/williamcheng/Desktop/AData Analyst/Restaurant/Prepaid_Order_2018VS2019.png"
Image(filename = path, width=1000, height=100)
